# %% [markdown]
# ### Imports Libraries

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
path_to_csv = "amazon-books-cleaned-data/books-data-csv2.csv"
df = pd.read_csv(path_to_csv)

# %%
df["title_len"] = df['Title'].str.len()

# %%
df['contains_subheading'] = df['Title'].str.contains(":",regex=False)

# %%
df["title_num_words"] = df['Title'].str.split().str.len()
df
# Out:
#                                                    Title  \
# 0      The Church of Christ: A Biblical Ecclesiology ...
# 1                A Walk in the Woods: a Play in Two Acts
# 2      Voices from the Farm: Adventures in Community ...
# 3                                The Battleship Bismarck
# 4                                         Mini-mysteries
# ...                                                  ...
# 49746                                        Thin Within
# 49747  The Awakening and Selected Stories (Modern Lib...
# 49748                                       Final things
# 49749  The Orphan Of Ellis Island (Time Travel Advent...
# 49750                                  The Autograph Man
#
#                                              description  \
# 0      In The Church of Christ: A Biblical Ecclesiolo...
# 1                                                    NaN
# 2      Twenty-five years ago, at the height of the co...
# ...

# %%
# from transformers import pipeline
# sentiment_pipeline = pipeline("sentiment-analysis")
# data = ["I love you", "I hate you"]
# sentiment_pipeline(data)

# %%
path_to_cleaned_data = "amazon-books-cleaned-data/cleaned-001.csv"
df2 = pd.read_csv(path_to_cleaned_data)
df2
# Out:
#                                                      title  \
# 0        The Church of Christ: A Biblical Ecclesiology ...
# 1        The Church of Christ: A Biblical Ecclesiology ...
# 2        The Church of Christ: A Biblical Ecclesiology ...
# 3        The Church of Christ: A Biblical Ecclesiology ...
# 4                  A Walk in the Woods: a Play in Two Acts
# ...                                                    ...
# 1639093  The Orphan Of Ellis Island (Time Travel Advent...
# 1639094                                  The Autograph Man
# 1639095                                  The Autograph Man
# 1639096                                  The Autograph Man
# 1639097                                  The Autograph Man
#
#                                                description  \
# 0        In The Church of Christ: A Biblical Ecclesiolo...
# 1        In The Church of Christ: A Biblical Ecclesiolo...
# 2        In The Church of Christ: A Biblical Ecclesiolo...
# ...
